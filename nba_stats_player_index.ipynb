# %%
import requests
import pandas as pd

# %%
season_id = '2021-22'
# for newest team info, change this id to next season

# %%
player_url = 'https://stats.nba.com/stats/playerindex?College=&Country=&DraftPick=&DraftRound=&DraftYear=&Height=&Historical=1&LeagueID=00&Season='+season_id+'&SeasonType=Regular%20Season&TeamID=0&Weight='

# %%
headers  = {
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'x-nba-stats-token': 'true',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'x-nba-stats-origin': 'stats',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'cors',
    'Referer': 'https://stats.nba.com/',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

# %%
response = requests.get(url=player_url, headers=headers).json()

# %%
player_info = response['resultSets'][0]['rowSet']

# %%
player_info[0]
# Out:
# [76001,
#  'Abdelnaby',
#  'Alaa',
#  'alaa-abdelnaby',
#  1610612757,
#  'blazers',
#  0,
#  'Portland',
#  'Trail Blazers',
#  'POR',
#  '30',
#  'F',
#  '6-10',
#  '240',
#  'Duke',
#  'USA',
#  1990,
#  1,
#  25,
#  None,
#  5.7,
#  3.3,
#  0.3,
#  'Career',
#  '1990',
#  '1994']

# %%
len(player_info[0])
# Out:
# 26

# %%
column_list = [
"PERSON_ID",
"PLAYER_LAST_NAME",
"PLAYER_FIRST_NAME",
"PLAYER_SLUG",
"TEAM_ID",
"TEAM_SLUG",
"IS_DEFUNCT",
"TEAM_CITY",
"TEAM_NAME",
"TEAM_ABBREVIATION",
"JERSEY_NUMBER",
"POSITION",
"HEIGHT",
"WEIGHT",
"COLLEGE",
"COUNTRY",
"DRAFT_YEAR",
"DRAFT_ROUND",
"DRAFT_NUMBER",
"ROSTER_STATUS",
"PTS",
"REB",
"AST",
"STATS_TIMEFRAME",
"FROM_YEAR",
"TO_YEAR",
]

# %%
player_df = pd.DataFrame(player_info, columns = column_list)

# %%
player_df.sample(10)
# Out:
#       PERSON_ID PLAYER_LAST_NAME PLAYER_FIRST_NAME      PLAYER_SLUG  \
# 2043       1942          Jamison            Harold   harold-jamison
# 3996     203474         Stephens                DJ      dj-stephens
# 2490      77379            Lewis              Fred       fred-lewis
# 3154      77747            Ogden            Carlos     carlos-ogden
# 1590      76882            Greer               Hal        hal-greer
# 3054     203517          Nedovic           Nemanja  nemanja-nedovic
# 3677     203135            Sacre            Robert     robert-sacre
# 4700       1748            Young          Korleone   korleone-young
# 3871      78171        Slaughter               Jim    jim-slaughter
# 2974       2069          Mottola             Hanno    hanno-mottola
#
#          TEAM_ID TEAM_SLUG  IS_DEFUNCT     TEAM_CITY TEAM_NAME  \
# 2043  1610612746  clippers           0            LA  Clippers
# 3996  1610612749     bucks           0     Milwaukee     Bucks
# 2490  1610610024      None           1     Baltimore   Bullets
# 3154  1610612755    sixers           0  Philadelphia     76ers
# 1590  1610612755    sixers           0  Philadelphia     76ers
# 3054  1610612744  warriors           0  Golden State  Warriors
# 3677  1610612747    lakers           0   Los Angeles    Lakers
# 4700  1610612765   pistons           0       Detroit   Pistons
# 3871  1610610024      None           1     Baltimore   Bullets
# 2974  1610612737     hawks           0       Atlanta     Hawks
#
#      TEAM_ABBREVIATION  ... DRAFT_YEAR DRAFT_ROUND DRAFT_NUMBER ROSTER_STATUS  \
# 2043               LAC  ...        NaN         NaN          NaN           NaN
# 3996               MIL  ...        NaN         NaN          NaN           NaN
# 2490               BAL  ...        NaN         NaN          NaN           NaN
# 3154               PHI  ...     1969.0         1.0         13.0           NaN
# 1590               PHI  ...     1958.0         2.0         13.0           NaN
# 3054               GSW  ...     2013.0         1.0         30.0           NaN
# 3677               LAL  ...     2012.0         2.0         60.0           NaN
# 4700               DET  ...     1998.0         2.0         40.0           NaN
# 3871               BAL  ...     1951.0         4.0         31.0           NaN
# 2974               ATL  ...     2000.0         2.0         40.0           NaN
#
#        PTS  REB  AST  STATS_TIMEFRAME  FROM_YEAR  TO_YEAR
# 2043   1.9  1.6  0.3           Career       1999     2002
# 3996   2.3  1.3  0.0           Career       2013     2018
# 2490   8.4  NaN  1.4           Career       1948     1949
# 3154   3.5  1.4  0.6           Career       1969     1970
# 1590  19.2  5.0  4.0           Career       1958     1972
# 3054   1.1  0.6  0.5           Career       2013     2013
# 3677   4.2  3.1  0.7           Career       2012     2015
# 4700   4.3  1.3  0.3           Career       1998     1998
# 3871   5.3  5.3  0.9           Career       1951     1951
# 2974   4.6  2.9  0.5           Career       2000     2001
#
# [10 rows x 26 columns]

# %%
player_df.to_csv('player_index.csv', index = False)

# %%
season_list = [
    '2016-17'
    '2017-18'
    '2018-19'
    '2019-20'
    '2020-21'
]
