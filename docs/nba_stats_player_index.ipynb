# %%
import requests
import pandas as pd

# %%
season_id = '2022-23'
# for newest team info, change this id to next season

# %%
player_url = 'https://stats.nba.com/stats/playerindex?College=&Country=&DraftPick=&DraftRound=&DraftYear=&Height=&Historical=1&LeagueID=00&Season='+season_id+'&SeasonType=Regular%20Season&TeamID=0&Weight='

# %%
headers  = {
    'Connection': 'keep-alive',
    'Accept': 'application/json, text/plain, */*',
    'x-nba-stats-token': 'true',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36',
    'x-nba-stats-origin': 'stats',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'cors',
    'Referer': 'https://stats.nba.com/',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9',
}

# %%
response = requests.get(url=player_url, headers=headers).json()

# %%
player_info = response['resultSets'][0]['rowSet']

# %%
player_info[0]
# Out:
# [76001,
#  'Abdelnaby',
#  'Alaa',
#  'alaa-abdelnaby',
#  1610612757,
#  'blazers',
#  0,
#  'Portland',
#  'Trail Blazers',
#  'POR',
#  '30',
#  'F',
#  '6-10',
#  '240',
#  'Duke',
#  'USA',
#  1990,
#  1,
#  25,
#  None,
#  5.7,
#  3.3,
#  0.3,
#  'Career',
#  '1990',
#  '1994']

# %%
len(player_info[0])
# Out:
# 26

# %%
column_list = [
"PERSON_ID",
"PLAYER_LAST_NAME",
"PLAYER_FIRST_NAME",
"PLAYER_SLUG",
"TEAM_ID",
"TEAM_SLUG",
"IS_DEFUNCT",
"TEAM_CITY",
"TEAM_NAME",
"TEAM_ABBREVIATION",
"JERSEY_NUMBER",
"POSITION",
"HEIGHT",
"WEIGHT",
"COLLEGE",
"COUNTRY",
"DRAFT_YEAR",
"DRAFT_ROUND",
"DRAFT_NUMBER",
"ROSTER_STATUS",
"PTS",
"REB",
"AST",
"STATS_TIMEFRAME",
"FROM_YEAR",
"TO_YEAR",
]

# %%
player_df = pd.DataFrame(player_info, columns = column_list)

# %%
player_df.sample(10)
# Out:
#       PERSON_ID PLAYER_LAST_NAME PLAYER_FIRST_NAME      PLAYER_SLUG  \
# 4399      78413            Verga               Bob        bob-verga
# 834       76438             Cook             Bobby       bobby-cook
# 2819      77528          McElroy               Jim      jim-mcelroy
# 2830      77534         McGregor               Gil     gil-mcgregor
# 3547     200810              Ray             Allan        allan-ray
# 4533     101110          Webster           Martell  martell-webster
# 775     1628492          Clavell              Gian     gian-clavell
# 4651       2421         Williams             Frank   frank-williams
# 1171    1631106            Eason              Tari       tari-eason
# 1900      77031           Hirsch               Mel       mel-hirsch
#
#          TEAM_ID  TEAM_SLUG  IS_DEFUNCT   TEAM_CITY      TEAM_NAME  \
# 4399  1610612757    blazers           0    Portland  Trail Blazers
# 834   1610610033       None           1   Sheboygan       Redskins
# ...

# %%
player_df.to_csv('player_index.csv', index = False)

# %%
season_list = [
    '2016-17'
    '2017-18'
    '2018-19'
    '2019-20'
    '2020-21'
    '2021-22'
]
